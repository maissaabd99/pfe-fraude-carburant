# %% [markdown]
# ## Nouvelle Approche : Clustering des matricules similaires en termes de caractéristiques pour prévenir l'overfitting de model de Isolation Forest

# %% [markdown]
# ### 1 - DBSCAN

# %%
#%matplotlib inline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest
import plotly.express as px
from mplcursors import cursor
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np
from sklearn.cluster import DBSCAN

# %%
dataframe = pd.read_csv("/Users/abdelwahed/Mise-en-place-dun-detecteur-de-fraude-de-carburant/gp2_carburant_transformed_diff_date.csv",delimiter=',')
dataframe.head()
# Out:
#    matricule        date  quantite  fournisseur  typePaiement  type_carburant  \
# 0        167  2022-09-01     33.52            0    1407051734               2
# 1        167  2022-09-07     27.93            0    1407051734               2
# 2        167  2022-09-15     22.35            0    1407051734               2
# 3        167  2022-10-01     26.88            0    1407051734               2
# 4        167  2022-10-10     26.88            0    1407051734               2
#
#    station  diff_date
# 0       41        8.0
# 1      111        6.0
# 2      111        8.0
# 3      118       16.0
# 4      111        9.0

# %%
X = dataframe.drop(['matricule','date','station'],axis =1)
y_pred = DBSCAN(eps = 0.1, min_samples = 5).fit_predict(X)
plt.scatter(dataframe['typePaiement'],dataframe['quantite'],c = y_pred)
